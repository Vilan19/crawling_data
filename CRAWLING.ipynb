# %% [markdown]
# <a href="https://colab.research.google.com/github/Vilan19/crawling_data/blob/main/CRAWLING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Crawling Data Using API

# %%
import googleapiclient.discovery
import pandas as pd

# %%
dev = "AIzaSyCmPAZwV726j_-egNtOgGy7UOxXJEoD_nA"
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY
)
request = youtube.commentThreads().list(
    part = "snippet",
    videoId = "epnC7Fwwd-E",
    maxResults = 1300
)

comments = []

#execute the request
response = request.execute()

#get comments from the response
for item in response['items']:
  comment = item['snippet']['topLevelComment']['snippet']
  public = item['snippet']['isPublic']
  comments.append([
      comment['authorDisplayName'],
      comment['publishedAt'],
      comment['likeCount'],
      comment['textOriginal'],
      public
  ])
while (1 == 1):
  try:
    nextPageToken = response['nextPageToken']
  except KeyError:
    break
  nextPageToken = response['nextPageToken']

  #create a new request object with the next page
  nextRequest = youtube.commentThreads().list(part="snippet", videoId = "epnC7Fwwd-E", maxResults = 1300, pageToken=nextPageToken)

  #execute the next request
  response = nextRequest.execute()

  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
      comment['authorDisplayName'],
      comment['publishedAt'],
      comment['likeCount'],
      comment['textOriginal'],
      public
  ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text', 'public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      927 non-null    object
#  1   updated_at  927 non-null    object
#  2   like_count  927 non-null    int64
#  3   text        927 non-null    object
#  4   public      927 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 30.0+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'EEXnRpt5FsDXkZroT_4pp5x_tPc',
#  'id': 'Ugx4ASgsFJa1VU6yd_94AaABAg',
#  'snippet': {'channelId': 'UC1dGHGJTXU_dkiR8tW3qQgg',
#   'videoId': 'epnC7Fwwd-E',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': '8wKGhrVvOR1k96bK3lbM0LP1uU4',
#    'id': 'Ugx4ASgsFJa1VU6yd_94AaABAg',
#    'snippet': {'channelId': 'UC1dGHGJTXU_dkiR8tW3qQgg',
#     'videoId': 'epnC7Fwwd-E',
#     'textDisplay': '<a href="https://www.youtube.com/watch?v=epnC7Fwwd-E&amp;t=420">7:00</a>',
#     'textOriginal': '7:00',
#     'authorDisplayName': '@rifqifircold4682',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mp_as9qKy1orFFCzVZklO0bhNspi1rizgbP9XFOjY=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@rifqifircold4682',
#     'authorChannelId': {'value': 'UC3F_YDUtKDg0hWDtworkQMQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 345,
#     'publishedAt': '2024-09-14T15:29:51Z',
# ...

# %%
df.head(1274)
# Out:
#                  author            updated_at  like_count  \
# 0    @elisalenasari5272  2024-11-01T05:31:17Z           0
# 1    @elisalenasari5272  2024-11-01T05:29:57Z           0
# 2     @AnisaNurul-wr1rw  2024-11-01T04:50:02Z           1
# 3       @saniarizka2465  2024-10-31T17:55:48Z           0
# 4     @BagasBagas-sn5yq  2024-10-31T03:47:36Z           0
# ..                  ...                   ...         ...
# 922         @nuraja5393  2024-09-14T15:28:17Z           1
# 923   @m.agusananda2262  2024-09-14T15:28:14Z           4
# 924    @AhmadZamzam-i1e  2024-09-14T15:28:09Z           0
# 925       @ayasetya6475  2024-09-14T15:28:06Z           0
# 926  @BalfourGPankhurst  2024-09-14T15:27:55Z           0
#
#                         text  public
# 0                       🔥🔥🔥🔥    True
# 1                      Onicc    True
# 2                   Sjjusjud    True
# 3                        hhh    True
# 4    Trevel kil ga ada kairi    True
# ..                       ...     ...
# ...

# %%
df.to_csv("data_komentar.csv")
